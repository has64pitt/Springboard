# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = 'XXXXX'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
url = "https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?start_date=2017-01-02&end_date=2017-01-03&api_key="+API_KEY
r = requests.get(url)
json_data = r.json()
print(json_data)
# Out:
# {'dataset': {'id': 10095370, 'dataset_code': 'AFX_X', 'database_code': 'FSE', 'name': 'Carl Zeiss Meditec (AFX_X)', 'description': 'Stock Prices for Carl Zeiss Meditec (2019-12-27) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704', 'refreshed_at': '2020-01-08T22:24:44.820Z', 'newest_available_date': '2020-01-08', 'oldest_available_date': '2000-06-07', 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'frequency': 'daily', 'type': 'Time Series', 'premium': False, 'limit': None, 'transform': None, 'column_index': None, 'start_date': '2017-01-02', 'end_date': '2017-01-03', 'data': [['2017-01-03', 35.9, 35.93, 35.34, 35.48, None, 70618.0, 2515473.0, None, None, None], ['2017-01-02', 34.99, 35.94, 34.99, 35.8, None, 44700.0, 1590561.0, None, None, None]], 'collapse': None, 'order': None, 'database_id': 6129}}

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
def pretty(d, indent=0):
    for key, value in d.items():
        print('\t' * indent + str(key))
        if isinstance(value, dict):
            pretty(value, indent+1)
        else:
            print('\t' * (indent+1) + str(value))
pretty(json_data)
# Out:
# dataset
# 	id
# 		10095370
# 	dataset_code
# 		AFX_X
# 	database_code
# 		FSE
# 	name
# 		Carl Zeiss Meditec (AFX_X)
# 	description
# 		Stock Prices for Carl Zeiss Meditec (2019-12-27) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704
# 	refreshed_at
# 		2020-01-08T22:24:44.820Z
# 	newest_available_date
# 		2020-01-08
# 	oldest_available_date
# 		2000-06-07
# 	column_names
# 		['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover']
# 	frequency
# 		daily
# 	type
# 		Time Series
# 	premium
# 		False
# 	limit
# 		None
# 	transform
# 		None
# 	column_index
# 		None
# 	start_date
# 		2017-01-02
# 	end_date
# 		2017-01-03
# 	data
# 		[['2017-01-03', 35.9, 35.93, 35.34, 35.48, None, 70618.0, 2515473.0, None, None, None], ['2017-01-02', 34.99, 35.94, 34.99, 35.8, None, 44700.0, 1590561.0, None, None, None]]
# 	collapse
# 		None
# 	order
# 		None
# 	database_id
# ...

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %% [markdown]
# # Solutions
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).

# %%
url = "https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?start_date=2017-01-01&end_date=2017-12-31&api_key="+API_KEY
r = requests.get(url)
json_data = r.json()

# %% [markdown]
# 2. Convert the returned JSON object into a Python dictionary.

# %%
column_names = json_data['dataset']['column_names']
column_names
# Out:
# ['Date',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Change',
#  'Traded Volume',
#  'Turnover',
#  'Last Price of the Day',
#  'Daily Traded Units',
#  'Daily Turnover']

# %%
price_data = json_data['dataset']['data']

# %%
mydictlist = [dict(zip(column_names,i))  for i in price_data]

# %% [markdown]
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.

# %%
open_price = [i['Open'] for i in mydictlist if i['Open'] ]
print('highest open price in 2017 = ', max(open_price))
print('lowest open price in 2017 = ',  min(open_price))

import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12,9))
plt.plot(open_price)
plt.axvline(open_price.index(max(open_price)), color='g',linestyle='-.')
plt.axvline(open_price.index(min(open_price)), color='r',linestyle='-.')
plt.xlim([0, len(open_price)])
plt.show()
# Out:
# highest open price in 2017 =  53.11
# lowest open price in 2017 =  34.0

# %% [markdown]
# 4. What was the largest change in any one day (based on High and Low price)?

# %%
daily_change = [i['High'] - i['Low'] for i in mydictlist]
print('max daily change = ', max(daily_change))

plt.figure(figsize=(12,9))
plt.plot(daily_change)
plt.axvline(daily_change.index(max(daily_change)), color='g',linestyle='-.')
plt.xlim([0, len(daily_change)])
plt.show()
# Out:
# max daily change =  2.8100000000000023

# %% [markdown]
# 5. What was the largest change between any two days (based on Closing Price)?

# %%
close_change = [mydictlist[i+1]['Close']- mydictlist[i]['Close'] for (i,dict) in enumerate(mydictlist[:-1])]
print('max close change between two days = ',max(close_change))

plt.figure(figsize=(12,9))
plt.plot(close_change)
plt.axvline(close_change.index(max(close_change)), color='g',linestyle='-.')
plt.xlim([0, len(close_change)])
plt.show()
# Out:
# max close change between two days =  2.559999999999995

# %% [markdown]
# 6. What was the average daily trading volume during this year?

# %%
from statistics import mean
daily_volume = [i['Traded Volume'] for i in mydictlist]
print('Avergae trading volume = ', mean(daily_volume))

plt.figure(figsize=(12,9))
plt.plot(daily_volume)
plt.axhline(mean(daily_volume), color='g',linestyle='-.')
plt.xlim([0, len(daily_volume)])
plt.show()
# Out:
# Avergae trading volume =  89124.33725490196

# %% [markdown]
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
daily_volume.sort()

if len(daily_volume)%2==0:
    print('Median for daily volume = ', 0.5*(daily_volume[len(daily_volume-2)//2] + daily_volume[len(daily_volume)//2]))
else:
    print('Median for daily volume = ', daily_volume[len(daily_volume)//2])
# Out:
# Median for daily volume =  76286.0
